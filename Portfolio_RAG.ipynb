# %%
# %pip install llama-index openai tiktoken pypdf
# %pip install llama-index-llms-openai llama-index-embeddings-openai
# %pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#Libraries
from llama_index.core import Document, VectorStoreIndex, Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from PyPDF2 import PdfReader
import os
from dotenv import load_dotenv
print("Library imported successfully")
# Out:
# Library imported successfully

# %%
# Load API key
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError("OPENAI_API_KEY not found! Please set it in your .env file.")

print("✅ API key loaded")
# Out:
# ✅ API key loaded

# %%
#Configure LlamaIndex
Settings.llm = OpenAI(model="gpt-3.5-turbo", temperature=0, api_key=openai_api_key)
Settings.embed_model = OpenAIEmbedding(api_key=openai_api_key)

#Obtain Document
reader = PdfReader("HALIMAT IBRAHIM_CV.pdf")

#Function to retrieve documents
def read_docs(paths: list) -> str:
    """
    Function to retrieve documents in pdf and text formats.
    Input: paths = list[str]
    output: retrieved_document = str
    """

    documents = {}
    for index, path in enumerate(paths):
        if path.endswith(".txt"):
            try:
                with open(path, "r") as f:
                    documents[f"doc_{index}"] = []
                    documents[f"doc_{index}"].append(f.read())
            except FileNotFoundError:
                print(f"File not found for {path}")
            except Exception as e:
                print(f"Error reading file {path}: {e}")
        elif path.endswith(".pdf"):
            try:
                reader = PdfReader(path)
                for i in range(len(reader.pages)):
                    if i == 0:
                        documents[f"doc_{index}"] = []
                    text = reader.pages[i].extract_text().strip()
                    if text:
                        documents[f"doc_{index}"].append(text)
            except FileNotFoundError:
                print(f"File not found for {path}")
            except Exception as e:
                print(f"Error reading file {path}: {e}")
    return ["\n".join(text_list) for text_list in documents.values()]


read_docs(["HALIMAT IBRAHIM_CV.pdf"])
# Out:
# ['HALIMATIBRAHIM-AKINOSO\nAIDeveloper|MachineLearningEngineer|Full-StackAIBuilder\nNigeria\nhalimahAkin2@gmail.com|GitHub:github.com/halimahAkinoso/\n|LinkedIn:linkedin.com/in/halimah-akinoso\nPROFESSIONALSUMMARY\nInnovativeAIDeveloperwithstrongexperienceinbuildingintelligentsystemsusingmachinelearning,\nnaturallanguageprocessing,andfull-stacktechnologies.SkilledindevelopingAI-powerededucational\nplatforms,RAGpipelines,anddata-drivenwebapplications.Passionateaboutapplyingartificial\nintelligencetosolvereal-worldproblemsineducation,commerce,andsocialimpact,particularlyin\nAfricancontexts.\nCORESKILLS\nArtificialIntelligence&MachineLearning\nMachineLearning(Supervised&UnsupervisedLearning)\nNaturalLanguageProcessing(NLP)\nRetrieval-AugmentedGeneration(RAG)\nPromptEngineering\nLargeLanguageModels(LLMs)\nTextEmbeddings&SemanticSearch\nProgramming&Tools\nPython,JavaScript\nTensorFlow,PyTorch\nLangChain,LlamaIndex\nOpenAIAPI\nHuggingFace\nScikit-learn,Pandas,NumPy\nWeb&ApplicationDevelopme
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\hp\\Desktop\\AI_TASKS'

# %%
#Create documents and index
documents = read_docs(["HALIMAT IBRAHIM_CV.pdf", "info.txt"])
llama_docs = [Document(text = doc) for doc in documents]
index = VectorStoreIndex.from_documents(llama_docs)

#Query
query_engine = index.as_query_engine()
response = query_engine.query("Provide a summary on Halimah Ibrahim Resume, with that summary give possible job roles or positions he can occupy")
# Out:
# File not found for info.txt

# %%
# Query
response = query_engine.query("Outside his resume and info file, what other things would he probably be interested in?")
